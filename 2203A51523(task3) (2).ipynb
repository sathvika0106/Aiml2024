# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv("/content/names.txt")

# display DataFrame
print(df1)
# Out:
#       names
# 0  sathvika
# 1      siri
# 2       sri

# %%
import numpy as np
import pandas as pd

# Assuming "Sheet1" is the name of the sheet you want to read from
df1 = pd.read_excel("/content/Book1.xlsx", sheet_name="Sheet1")

# Display DataFrame
print(df1)
# Out:
#      student  Hllno.
# 0   Sathvika     523
# 1        sri     522
# 2   Shaistha     521
# 3   Varshini     468
# 4  Varshitha     519

# %%
import pandas as pd

# Read DataFrame from CSV file
df1 = pd.read_csv("/content/ss.csv")

# Display DataFrame
print(df1)
# Out:
#   student  roll  age
# 0    sath   523   18
# 1     sri   522   19
# 2   shais   521   19

# %%
import pandas as pd

# Read DataFrame from TSV file
df1 = pd.read_csv("/content/sample-1.tsv", delimiter='\t')

# Display DataFrame
print(df1)
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN    JANUARY        NaN        NaN        NaN        NaN
# 1          NaN          S          M          T          W          T
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN          2          3          4          5          6
# 4          NaN          9         10         11         12         13
# 5          NaN         16         17         18         19         20
# 6          NaN         23         24         25         26         27
# 7          NaN         30         31        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN     APRIL         NaN        NaN        NaN        NaN
# 10         NaN          S          M          T          W          T
# 11         NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
import pandas as pd

# Read DataFrame from TSV file, skipping lines with too many fields
df1 = pd.read_csv("/content/sample-1.tsv", delimiter='\t')

# Display DataFrame
print(df1)
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN    JANUARY        NaN        NaN        NaN        NaN
# 1          NaN          S          M          T          W          T
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN          2          3          4          5          6
# 4          NaN          9         10         11         12         13
# 5          NaN         16         17         18         19         20
# 6          NaN         23         24         25         26         27
# 7          NaN         30         31        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN     APRIL         NaN        NaN        NaN        NaN
# 10         NaN          S          M          T          W          T
# 11         NaN        NaN        NaN        NaN        NaN        NaN
# ...
